# %% [markdown]
# **Data Collection and Preparation**

# %% [markdown]
# **Importing all neccessary libraries**

# %%
import pandas as pd
import requests
import yfinance as yf
import nasdaqdatalink
import quandl

# %% [markdown]
# **Getting data about Bitcoin from Lunar API**

# %%
# Requesting the Bitcoin Data from Lunar and putting into CSV file: 
# (Date Range: 12th June 2020 - 8th March 2023)

# url = "https://lunarcrush.com/api3/coins/1/time-series?interval=all&start=%091591912800&bucket=day&data_points=1000"
# headers = {
#   'Authorization': 'Bearer czafphn2g5ln3tzinz5qd6bkxlf2f0y70cun8xs2r'

# response = requests.request("GET", url, headers=headers)
# response

# print(response.text.encode('utf8'))

# call = response.text.encode('utf8')

# response.content

# data1 = response.json()

# data1["timeSeries"]

# df = pd.json_normalize(data1["timeSeries"])

# df.to_csv('BitcoinLunarData', index=False)

# %%
df_luna = pd.read_csv('./data/BitcoinLunarData.csv')
df_luna.head()
# Out:
#    asset_id        time         open        close         high          low  \
# 0         1  1591920000  9320.690855  9480.843789  9540.465393  9285.851404
# 1         1  1592006400  9480.735750  9475.277338  9493.211715  9396.009394
# 2         1  1592092800  9477.554037  9386.787892  9482.270936  9347.593793
# 3         1  1592179200  9386.035291  9450.701987  9504.860065  8990.175947
# 4         1  1592265600  9454.266431  9538.024374  9579.430375  9400.445008
#
#          volume    volume_24h    market_cap  circulating_supply  ...  \
# 0  2.980465e+10  2.261056e+10  1.744749e+11            18402731  ...
# 1  2.305366e+10  1.756432e+10  1.743818e+11            18403818  ...
# 2  2.274307e+10  1.899173e+10  1.727632e+11            18404243  ...
# 3  3.664421e+10  2.669970e+10  1.739476e+11            18404950  ...
# 4  2.862811e+10  2.156554e+10  1.755640e+11            18405843  ...
#
#    influential_content  influential_content_score       sma_50      sma_100  \
# ...

# %%
#12th June 2020 - September 16th 2017

# url = "https://lunarcrush.com/api3/coins/1/time-series?interval=1d&start=%091505512800&bucket=day&data_points=1000"
# headers = {
#   'Authorization': 'Bearer czafphn2g5ln3tzinz5qd6bkxlf2f0y70cun8xs2r'
# }

# response2 = requests.request("GET", url, headers=headers)

# print(response2.text.encode('utf8'))

# print(response2.text.encode('utf8'))

# call2 = response2.text.encode('utf8')

# response2.content

# data2 = response2.json()

# data2["timeSeries"]

# df2 = pd.json_normalize(data2["timeSeries"])

# df2.to_csv('BitcoinLunarData2', index=False)

# %%
df2_luna = pd.read_csv('./data/BitcoinLunarData2.csv')
df2_luna.head()
# Out:
#    asset_id        time     open        close     high      low        volume  \
# 0         1  1505520000  3637.75  3637.750000  3808.84  3487.79  2.119428e+09
# 1         1  1505606400  3606.28  3606.280029  3664.81  3445.64  1.285886e+09
# 2         1  1505692800  3591.09  3591.090088  4079.23  3591.09  2.133420e+09
# 3         1  1505779200  4073.79  4073.790039  4094.07  3868.87  1.718896e+09
# 4         1  1505865600  3916.36  3916.360107  4031.39  3857.73  1.250133e+09
#
#      volume_24h    market_cap  circulating_supply  ...  influential_content  \
# 0  1.818400e+09  6.027929e+10            16570450  ...                  NaN
# 1  1.239150e+09  5.976580e+10            16572662  ...                  NaN
# 2  1.943210e+09  5.951989e+10            16574262  ...                  NaN
# 3  1.563980e+09  6.752806e+10            16576225  ...                  NaN
# 4  1.213830e+09  6.492439e+10            16577725  ...                  NaN
#
# ...

# %%
#Finding the point where tweets has NaN values
num_nan_tweets = df2_luna['tweets'].isnull().sum()
num_nan_tweets
# Out:
# 712

# %%
#Dropping rows beyond which there are no tweet data
df2dropped_luna = df2_luna.drop(index=df2_luna.index[:712])
df2dropped_luna
# Out:
#      asset_id        time         open         close          high  \
# 712         1  1567036800  9756.785707   9510.200544   9756.785707
# 713         1  1567123200  9514.844852   9598.173648   9656.123926
# 714         1  1567209600  9597.539448   9630.663848   9673.220440
# 715         1  1567296000  9630.593196   9757.970318   9796.755968
# 716         1  1567382400  9757.473237  10346.760793  10396.591325
# ..        ...         ...          ...           ...           ...
# 995         1  1591488000  9653.003325   9758.852417   9768.497902
# 996         1  1591574400  9760.063252   9771.489484   9782.306497
# 997         1  1591660800  9774.359936   9795.700195   9836.368969
# 998         1  1591747200  9794.119511   9870.094453   9908.896559
# 999         1  1591833600  9870.078529   9321.781298   9938.297674
#
#              low        volume    volume_24h    market_cap  \
# 712  9421.630160  1.544143e+10  1.704588e+10  1.702749e+11
# ...

# %%
#Merging the older and more recent dataframes
merged_df = pd.concat([df2dropped_luna, df_luna], ignore_index=True)

#Creating a dattime column by converting the UNIX time format
merged_df['date'] = pd.to_datetime(merged_df['time'], unit='s')

#Creating a Day of the Month column 
merged_df['Day of Month'] = merged_df['date'].dt.day

#Creating a month column 
merged_df['month'] = merged_df['date'].dt.month

#Creating a % change column
merged_df['Daily % Change'] = merged_df['close'].pct_change() * 100

#Dropping Asset id column 
merged_df.drop('asset_id', axis=1, inplace=True)

#Indexing to date
merged_df.set_index('date', inplace=True)

#Exporting to CSV
merged_df.to_csv('./data/lunarmerged_df.csv', index=True)

# %%
lunarmerged_df = pd.read_csv('./data/lunarmerged_df.csv')

# %% [markdown]
# **Getting other financial data from YFinance to be used as features**

# %%
#Getting Data from Yfinance

# Set the start and end dates
start_date = '2019-08-29'
end_date = '2023-03-08'

# Get the S&P 500 daily performance data
sp500_df = yf.download('^GSPC', start=start_date, end=end_date, progress=False)
sp500_daily_performance = (sp500_df['Close'] - sp500_df['Open']) / sp500_df['Open'] * 100

# Get the NASDAQ 100 daily performance data
nasdaq100_df = yf.download('^NDX', start=start_date, end=end_date, progress=False)
nasdaq100_daily_performance = (nasdaq100_df['Close'] - nasdaq100_df['Open']) / nasdaq100_df['Open'] * 100

# Get the treasury bond rate data
treasury_bond_rates_df = yf.download('^TNX', start=start_date, end=end_date, progress=False)
treasury_5yr_bond_rate = treasury_bond_rates_df['Close'].resample('D').last().ffill()
treasury_10yr_bond_rate = treasury_bond_rates_df['Close'].resample('D').last().ffill()
treasury_30yr_bond_rate = treasury_bond_rates_df['Close'].resample('D').last().ffill()

# Get the 1-year treasury bond rate data
treasury_1yr_bond_rates_df = yf.download('^IRX', start=start_date, end=end_date, progress=False)
treasury_1yr_bond_rate = treasury_1yr_bond_rates_df['Close'].resample('D').last().ffill()

# Get the bitcoin futures data
bitcoin_futures_df = yf.download('BTC=F', start=start_date, end=end_date, progress=False)
bitcoin_futures_volume = bitcoin_futures_df['Volume']
bitcoin_futures_daily_returns = (bitcoin_futures_df['Close'] - bitcoin_futures_df['Open']) / bitcoin_futures_df['Open'] * 100
bitcoin_futures_volatility = bitcoin_futures_daily_returns.std()

# Combine the data into a single DataFrame
data = {'S&P 500 Daily Performance': sp500_daily_performance,
        'NASDAQ 100 Daily Performance': nasdaq100_daily_performance,
        '1-Year Treasury Bond Rate': treasury_1yr_bond_rate,
        '5-Year Treasury Bond Rate': treasury_5yr_bond_rate,
        '10-Year Treasury Bond Rate': treasury_10yr_bond_rate, 
        '30-Year Treasury Bond Rate': treasury_30yr_bond_rate,
        'Bitcoin Futures Volume' : bitcoin_futures_volume, 
        'Bitcoin Futures Returns' : bitcoin_futures_daily_returns,
        'Bitcoin Futures Volatility': bitcoin_futures_volatility}

yfinance_data = pd.DataFrame(data)

# %%
#Dropping Volatility column 
yfinance_data.drop(columns=['Bitcoin Futures Volatility'], inplace=True)

# %%
#Exporting to CSV
yfinance_data.to_csv('./data/yfinance_data.csv', index=True)

# %%
#Loading from CSV
yfinance_data = pd.read_csv('./data/yfinance_data.csv')

# %% [markdown]
# **Preliminary cleaning and joining YFinance with Lunar data**

# %%
#Merging y_finance data with lunar crush data
# Merge the two DataFrames based on their common date index
merged_df = lunarmerged_df.merge(yfinance_data, left_index=True, right_index=True)
# Out:
#             date        time          open         close          high  \
# 0     2019-08-29  1567036800   9756.785707   9510.200544   9756.785707
# 1     2019-08-30  1567123200   9514.844852   9598.173648   9656.123926
# 2     2019-08-31  1567209600   9597.539448   9630.663848   9673.220440
# 3     2019-09-01  1567296000   9630.593196   9757.970318   9796.755968
# 4     2019-09-02  1567382400   9757.473237  10346.760793  10396.591325
# ...          ...         ...           ...           ...           ...
# 1282  2023-03-03  1677801600  23476.633731  22362.679332  23479.348094
# 1283  2023-03-04  1677888000  22362.923027  22353.350074  22405.176954
# 1284  2023-03-05  1677974400  22354.143598  22435.514197  22613.685231
# 1285  2023-03-06  1678060800  22436.816776  22429.757533  22584.293809
# 1286  2023-03-07  1678147200  22428.322390  22219.769071  22527.418642
#
#                low        volume    volume_24h    market_cap  \
# ...

# %%
#Dropping some unnecessary columns
merged_df.drop(columns=['time', 'volume', 'tweet_followers', 'tweet_quotes', 'tweet_retweets', 'tweet_replies', 'sentiment_absolute', 'sentiment_relative', 'tweet_favorites', 'search_average', 'volume', 'reddit_posts', 'reddit_posts_score', 'reddit_comments', 'reddit_comments_score', 'alt_rank', 'alt_rank_30d', 'alt_rank_hour_average', 'market_cap_rank', 'percent_change_24h_rank', 'volume_24h_rank', 'social_volume_24h_rank', 'social_score_24h_rank', 'medium', 'youtube', 'influential_content', 'influential_content_score', 'Date'], inplace=True)

# %%
merged_df.to_csv('./data/YfLunar_merged_df.csv', index=False)

# %% [markdown]
# **Getting data about bitcoin mining from Nasdaq/Quandle**

# %%
# Set the Quandl API key
quandl.ApiConfig.api_key = 'j1bxx9Kr2WVUiCkTus-u'

# Define the data products and time range
data_products = ['BCHAIN/AVBLS', 'BCHAIN/HRATE', 'BCHAIN/CPTRA', 'BCHAIN/DIFF']
start_date = '2019-08-28'
end_date = '2023-03-08'

# Retrieve the data for each data product and concatenate into a single dataframe
dfs = []
for product in data_products:
    df = quandl.get(product, start_date=start_date, end_date=end_date)
    df.columns = [product.split('/')[1]] # Rename the column to the data product code
    dfs.append(df)
df = pd.concat(dfs, axis=1)

# Convert the index to a datetime object and sort the dataframe by date
df.index = pd.to_datetime(df.index)
df = df.sort_index()

# Print the resulting dataframe
print(df)
# Out:
#                AVBLS         HRATE      CPTRA          DIFF
# Date
# 2019-08-28  1.038467  7.643982e+07  56.521522  1.018349e+13
# 2019-08-29  0.995517  8.352695e+07  57.337225  1.018349e+13
# 2019-08-30  1.005411  8.099583e+07  55.423721  1.018349e+13
# 2019-08-31  0.874326  8.403318e+07  58.942276  1.018349e+13
# 2019-09-01  0.885620  7.595912e+07  60.905440  1.068557e+13
# ...              ...           ...        ...           ...
# 2023-03-04  2.145610  3.253132e+08  71.259805  4.305384e+13
# 2023-03-05  1.933651  3.317338e+08  77.165487  4.305384e+13
# 2023-03-06  1.809957  2.825088e+08  60.900910  4.305384e+13
# 2023-03-07  2.018769  3.531360e+08  65.223410  4.305384e+13
# 2023-03-08  1.980563  2.846490e+08  64.716008  4.305384e+13
#
# [1289 rows x 4 columns]

# %%
df.to_csv('./data/mining_data.csv', index=True)

# %% [markdown]
# **Getting data about 2 other cryptocurrencies**

# %%
#Getting additional data from Yfinance

assets = ['ETH-USD', 'DOGE-USD']
start_date = '2019-08-28'
end_date = '2023-03-08'

dfs = []
for asset in assets:
    df = yf.download(asset, start=start_date, end=end_date, progress=False)
    df = df['Close'].rename(asset.replace('^', '').replace('-', '_'))
    dfs.append(df)
    
df_final = pd.concat(dfs, axis=1)
print(df_final.head())
# Out:
#                               ETH_USD  DOGE_USD
# Date
# 2019-08-28 00:00:00+00:00  173.889969  0.002524
# 2019-08-29 00:00:00+00:00  169.516739  0.002450
# 2019-08-30 00:00:00+00:00  168.834869  0.002482
# 2019-08-31 00:00:00+00:00  172.469788  0.002511
# 2019-09-01 00:00:00+00:00  171.629425  0.002492

# %%
df_final.to_csv('./data/ETHDOGE.csv', index=True)

# %% [markdown]
# **Getting data about economic/finacial indices**

# %%
#Function to fill in the missing dates (eg weekends/holidays)

def fill_missing_values(df_name, start_date, end_date):
    # create a DatetimeIndex with every day from start date to end date
    idx = pd.date_range(start=start_date, end=end_date, freq='D')

    # create a DataFrame with the DatetimeIndex
    df = pd.DataFrame(index=idx)
    
    df_name.index = pd.DatetimeIndex(df_name.index).tz_localize(None)

    # merge the original DataFrame with the one with the DatetimeIndex
    df = df.merge(df_name, how='left', left_index=True, right_index=True)

    # fill missing values with previous day's values
    df.fillna(method='ffill', inplace=True)

    return df

# %%
#Function to clean and reformat the dataframes

def clean_data(data, ticker_name):
    # select only 'Open' and 'Close' columns
    data = data[['Open', 'Close']].copy()

    # rename columns with ticker symbol
    data.columns = [f"{ticker_name} {col}" for col in data.columns]

    # set index as a datetime object
    data.index = pd.to_datetime(data.index)

    # drop columns before 2019-08-29 and after 2023-03-08
    data = data.loc['2019-08-29':'2023-03-08']

    return data

# %%
#Retrieving data about indices from Yfinance

# Define dictionary of ticker_name : ticker
tickers = {'Nikkei 225': '^N225',
           'S&P 500': '^GSPC',
           'US Dollar Index': 'DX-Y.NYB',
           'Dow Jones Industrial Average': '^DJI',
           'Crude Oil': 'CL=F',
           'NASDAQ Composite': '^IXIC'}

# Retrieve and clean data for each ticker
dfs = []
for ticker_name, ticker in tickers.items():
    # Retrieve data
    data = yf.Ticker(ticker).history(period='5y', interval='1d')

    # Clean data
    data = clean_data(data, ticker_name)

    # Fill missing values
    data = fill_missing_values(data, '2019-08-29', '2023-03-08')

    # Append to list of data frames
    dfs.append(data)

# %%
indices_data = pd.concat(dfs, axis=1)

# %%
indices_data.to_csv('./data/indices_data.csv', index=True)

# %% [markdown]
# **Loading all the data from CSV files and then merging into a master dataframe**

# %%
indices_df = pd.read_csv('./data/indices_data.csv')

# %%
YfLunar_merged_df = pd.read_csv('./data/YfLunar_merged_df.csv')

# %%
mining_df = pd.read_csv('./data/mining_data.csv')

# %%
ETHDOGE_df = pd.read_csv('./data/ETHDOGE.csv')

# %%
allmerged_df = pd.concat([YfLunar_merged_df, ETHDOGE_df, indices_df, mining_df, ], axis=1)

# %%
allmerged_df
# Out:
#             date          open         close          high           low  \
# 0     2019-08-29   9756.785707   9510.200544   9756.785707   9421.630160
# 1     2019-08-30   9514.844852   9598.173648   9656.123926   9428.302397
# 2     2019-08-31   9597.539448   9630.663848   9673.220440   9531.799839
# 3     2019-09-01   9630.593196   9757.970318   9796.755968   9582.944631
# 4     2019-09-02   9757.473237  10346.760793  10396.591325   9730.650717
# ...          ...           ...           ...           ...           ...
# 1284  2023-03-05  22354.143598  22435.514197  22613.685231  22307.143313
# 1285  2023-03-06  22436.816776  22429.757533  22584.293809  22331.314828
# 1286  2023-03-07  22428.322390  22219.769071  22527.418642  22011.262497
# 1287         NaN           NaN           NaN           NaN           NaN
# 1288         NaN           NaN           NaN           NaN           NaN
#
#         volume_24h    market_cap  circulating_supply  url_shares  \
# ...

# %% [markdown]
# **Cleaning the master dataframe**

# %%
# Drop the excess date columns
allmerged_df = allmerged_df.drop(['Unnamed: 0', 'Date', 'Date'], axis=1)

# Drop the last two rows
allmerged_df = allmerged_df.iloc[:-2]

# %%
#Creating a close+1 column which will be my Time target variable 
allmerged_df['close+1'] = allmerged_df['close'].shift(-1)

# %%
#Replacing weekend values (currenty NaN) with 0s
allmerged_df[['NASDAQ 100 Daily Performance', 'S&P 500 Daily Performance', 'Bitcoin Futures Volume', 'Bitcoin Futures Returns']] = allmerged_df[['NASDAQ 100 Daily Performance', 'S&P 500 Daily Performance', 'Bitcoin Futures Volume', 'Bitcoin Futures Returns']].fillna(0)

# %%
# #Exporting to CSV
# allmerged_df.to_csv('./data/data_complete.csv', index=False)

# %%
allmerged_df
# Out:
#             date          open         close          high           low  \
# 0     2019-08-29   9756.785707   9510.200544   9756.785707   9421.630160
# 1     2019-08-30   9514.844852   9598.173648   9656.123926   9428.302397
# 2     2019-08-31   9597.539448   9630.663848   9673.220440   9531.799839
# 3     2019-09-01   9630.593196   9757.970318   9796.755968   9582.944631
# 4     2019-09-02   9757.473237  10346.760793  10396.591325   9730.650717
# ...          ...           ...           ...           ...           ...
# 1282  2023-03-03  23476.633731  22362.679332  23479.348094  22213.237594
# 1283  2023-03-04  22362.923027  22353.350074  22405.176954  22198.981009
# 1284  2023-03-05  22354.143598  22435.514197  22613.685231  22307.143313
# 1285  2023-03-06  22436.816776  22429.757533  22584.293809  22331.314828
# 1286  2023-03-07  22428.322390  22219.769071  22527.418642  22011.262497
#
#         volume_24h    market_cap  circulating_supply  url_shares  \
# ...

# %% [markdown]
# **Final check**

# %%
#Checking for NaN values
allmerged_df.isna().sum()
# Out:
# date       0
# open       0
# close      0
# high       0
# low        0
#           ..
# AVBLS      0
# HRATE      0
# CPTRA      0
# DIFF       0
# close+1    1
# Length: 69, dtype: int64

# %%
# create a boolean mask of NaN values
mask = allmerged_df.isna().any(axis=1)

# %%
allmerged_df[mask]
# Out:
#             date          open         close          high           low  \
# 0     2019-08-29   9756.785707   9510.200544   9756.785707   9421.630160
# 1286  2023-03-07  22428.322390  22219.769071  22527.418642  22011.262497
#
#         volume_24h    market_cap  circulating_supply  url_shares  \
# 0     1.704588e+10  1.702749e+11          17902412.0        80.0
# 1286  2.276545e+10  4.290907e+11          19311281.0     59540.0
#
#       unique_url_shares  ...  Dow Jones Industrial Average Close  \
# 0                  80.0  ...                        26362.250000
# 1286             6450.0  ...                        32856.460938
#
#       Crude Oil Open  Crude Oil Close  NASDAQ Composite Open  \
# 0          55.880001        56.709999            7945.779785
# 1286       80.500000        77.580002           11670.980469
#
#       NASDAQ Composite Close     AVBLS         HRATE      CPTRA          DIFF  \
# 0                7973.390137  1.038467  7.643982e+07  56.521522  1.018349e+13
# ...

# %%
# drop the first row of data
allmerged_df = allmerged_df.drop(index=0)

# Drop the last row
allmerged_df = allmerged_df.iloc[:-2]

# %%
#Moving close+1 next to the close column
allmerged_df.insert(3, "close+1", allmerged_df.pop("close+1"))

# %%
#Final check of dataframe
allmerged_df
# Out:
#             date          open         close       close+1          high  \
# 1     2019-08-30   9514.844852   9598.173648   9630.663848   9656.123926
# 2     2019-08-31   9597.539448   9630.663848   9757.970318   9673.220440
# 3     2019-09-01   9630.593196   9757.970318  10346.760793   9796.755968
# 4     2019-09-02   9757.473237  10346.760793  10623.540117  10396.591325
# 5     2019-09-03  10345.725140  10623.540117  10594.493354  10736.104721
# ...          ...           ...           ...           ...           ...
# 1280  2023-03-01  23150.929958  23646.549899  23475.466738  23880.632463
# 1281  2023-03-02  23647.019473  23475.466738  22362.679332  23739.138077
# 1282  2023-03-03  23476.633731  22362.679332  22353.350074  23479.348094
# 1283  2023-03-04  22362.923027  22353.350074  22435.514197  22405.176954
# 1284  2023-03-05  22354.143598  22435.514197  22429.757533  22613.685231
#
#                low    volume_24h    market_cap  circulating_supply  \
# ...

# %%
#Exporting to CSV
allmerged_df.to_csv('./data/data_complete_final.csv', index=False)

# %% [markdown]
# **Data is prepared. Ready to move on to prediction**
